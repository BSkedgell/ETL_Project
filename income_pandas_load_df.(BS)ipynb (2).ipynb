# %%
import csv
import pandas as pd
from sqlalchemy import create_engine

# %%
income1 = pd.read_csv('https://usc.data.socrata.com/api/views/kygc-fzgm/rows.csv?accessType=DOWNLOAD')
income1.head()
# Out:
#            Policy Area Dataset                 Variable  Year    Amount  \
# 0  Employment & Income  Income  Median Household Income  2013   74971.0
# 1  Employment & Income  Income  Median Household Income  2013   30759.0
# 2  Employment & Income  Income  Median Household Income  2011   57219.0
# 3  Employment & Income  Income  Median Household Income  2013   81700.0
# 4  Employment & Income  Income  Median Household Income  2011  101783.0
#
#                                                Tract  Tract Number  \
# 0  Census Tract 4321.01, Los Angeles County, Cali...        432101
# 1  Census Tract 2422, Los Angeles County, California        242200
# 2  Census Tract 2719.02, Los Angeles County, Cali...        271902
# 3  Census Tract 4313, Los Angeles County, California        431300
# 4  Census Tract 4805, Los Angeles County, California        480500
#
#         Neighborhood                 GEOID                   Location  \
# 0        Temple City  1400000US06037432101  (34.095852, -118.0428825)
# 1              Watts  1400000US06037242200   (33.948204, -118.238625)
# 2          Mar Vista  1400000US06037271902  (34.009731, -118.4316705)
# 3  Mayflower Village  1400000US06037431300  (34.1248395, -118.007363)
# 4     South Pasadena  1400000US06037480500   (34.1074225, -118.14498)
#
#                                               Row ID        Date
# 0  Median_Household_Income_2013_1400000US06037432101  01/01/2013
# 1  Median_Household_Income_2013_1400000US06037242200  01/01/2013
# 2  Median_Household_Income_2011_1400000US06037271902  01/01/2011
# 3  Median_Household_Income_2013_1400000US06037431300  01/01/2013
# 4  Median_Household_Income_2011_1400000US06037480500  01/01/2011

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
income = income1[["Year", "Amount", "Tract Number", "Neighborhood"]].copy()
income.head()
# Out:
#                   Variable  Year    Amount  Tract Number       Neighborhood
# 0  Median Household Income  2013   74971.0        432101        Temple City
# 1  Median Household Income  2013   30759.0        242200              Watts
# 2  Median Household Income  2011   57219.0        271902          Mar Vista
# 3  Median Household Income  2013   81700.0        431300  Mayflower Village
# 4  Median Household Income  2011  101783.0        480500     South Pasadena

# %%
income.index.names = ['id']
income
# Out:
#                       Variable  Year    Amount  Tract Number  \
# id
# 0      Median Household Income  2013   74971.0        432101
# 1      Median Household Income  2013   30759.0        242200
# 2      Median Household Income  2011   57219.0        271902
# 3      Median Household Income  2013   81700.0        431300
# 4      Median Household Income  2011  101783.0        480500
# 5      Median Household Income  2013   67816.0        700902
# 6      Median Household Income  2010   28510.0        910403
# 7      Median Household Income  2013       NaN        980020
# 8      Median Household Income  2012   64025.0        269906
# 9      Median Household Income  2010       NaN        901003
# 10     Median Household Income  2014   53516.0        201501
# 11     Median Household Income  2010  120515.0        800324
# 12     Median Household Income  2013   77377.0        264103
# 13     Median Household Income  2011   48365.0        500500
# 14     Median Household Income  2013   40401.0        570601
# 15     Median Household Income  2014   47633.0        570601
# 16     Median Household Income  2014   63500.0        402705
# 17     Median Household Income  2011  213347.0        262100
# 18     Median Household Income  2010   45330.0        542105
# 19     Median Household Income  2013   79235.0        482600
# 20     Median Household Income  2010   64861.0        272301
# 21     Median Household Income  2015   73417.0        278001
# 22     Median Household Income  2013   47935.0        500600
# 23     Median Household Income  2010   34500.0        500402
# 24     Median Household Income  2014   37398.0        533002
# 25     Median Household Income  2016   28375.0        209510
# 26     Median Household Income  2016   71806.0        603500
# 27     Median Household Income  2016   95080.0        702102
# 28     Median Household Income  2014   20972.0        572500
# 29     Median Household Income  2013   98625.0        143902
# ...                        ...   ...       ...           ...
# 16370  Median Household Income  2016  126406.0        111204
# 16371  Median Household Income  2010   47179.0        217200
# 16372  Median Household Income  2012   78232.0        602700
# 16373  Median Household Income  2010   41759.0        201401
# 16374  Median Household Income  2013   47284.0        920038
# 16375  Median Household Income  2010   83000.0        131100
# 16376  Median Household Income  2011   37840.0        127210
# 16377  Median Household Income  2011       NaN        980013
# 16378  Median Household Income  2016   40278.0        542105
# 16379  Median Household Income  2010   21167.0        224200
# 16380  Median Household Income  2011   60385.0        910001
# 16381  Median Household Income  2016   68750.0        406000
# 16382  Median Household Income  2016   78210.0        554514
# 16383  Median Household Income  2013   68793.0        554700
# 16384  Median Household Income  2015  102500.0        571800
# 16385  Median Household Income  2012   91711.0        920012
# 16386  Median Household Income  2015   77958.0        296401
# 16387  Median Household Income  2015   56898.0        532102
# 16388  Median Household Income  2016   29564.0        190402
# 16389  Median Household Income  2012   28735.0        600202
# 16390  Median Household Income  2016   51875.0        600911
# 16391  Median Household Income  2014   39789.0        551101
# 16392  Median Household Income  2010   35167.0        222100
# 16393  Median Household Income  2013   36398.0        120400
# 16394  Median Household Income  2015   94821.0        403702
# 16395  Median Household Income  2016   25517.0        224200
# 16396  Median Household Income  2010  107000.0        920039
# 16397  Median Household Income  2014   61496.0        404903
# 16398  Median Household Income  2013  103922.0        800329
# 16399  Median Household Income  2012   27396.0        535603
#
#                                 Neighborhood
# id
# 0                                Temple City
# 1                                      Watts
# 2                                  Mar Vista
# 3                          Mayflower Village
# 4                             South Pasadena
# 5                              Beverly Hills
# 6                                   Palmdale
# 7                               Shadow Hills
# 8                                      Palms
# 9                                  Lancaster
# 10                                 El Sereno
# 11                              Agoura Hills
# 12                                 Brentwood
# 13                               Pico Rivera
# 14                                Long Beach
# 15                                Long Beach
# 16                                    Pomona
# 17                             Beverly Crest
# 18                                   Compton
# 19                             Monterey Park
# 20                                 Mar Vista
# 21                               Westchester
# 22                               Pico Rivera
# 23                               Pico Rivera
# 24                           Huntington Park
# 25                                  Westlake
# 26                                   Gardena
# 27                              Santa Monica
# 28                                Long Beach
# 29                              Sherman Oaks
# ...                                      ...
# 16370                           Porter Ranch
# 16371                           Mid-Wilshire
# 16372                              Hawthorne
# 16373                              El Sereno
# 16374                          Santa Clarita
# 16375                            Lake Balboa
# 16376                               Van Nuys
# 16377                             El Segundo
# 16378                                Compton
# 16379                             Pico-Union
# 16380                               Palmdale
# 16381                                 Covina
# 16382                               Cerritos
# 16383                                Norwalk
# 16384                             Long Beach
# 16385                        Castaic Canyons
# 16386                              San Pedro
# 16387                             Montebello
# 16388                              Los Feliz
# 16389                               Westmont
# 16390                              Inglewood
# 16391                                 Downey
# 16392                        Adams-Normandie
# 16393                          Panorama City
# 16394                                 Covina
# 16395                             Pico-Union
# 16396                          Santa Clarita
# 16397                           Baldwin Park
# 16398  Unincorporated Santa Monica Mountains
# 16399                             South Gate
#
# [16400 rows x 5 columns]

# %%
income.index = income.index + 1
income
# Out:
#                       Variable  Year    Amount  Tract Number  \
# id
# 1      Median Household Income  2013   74971.0        432101
# 2      Median Household Income  2013   30759.0        242200
# 3      Median Household Income  2011   57219.0        271902
# 4      Median Household Income  2013   81700.0        431300
# 5      Median Household Income  2011  101783.0        480500
# 6      Median Household Income  2013   67816.0        700902
# 7      Median Household Income  2010   28510.0        910403
# 8      Median Household Income  2013       NaN        980020
# 9      Median Household Income  2012   64025.0        269906
# 10     Median Household Income  2010       NaN        901003
# 11     Median Household Income  2014   53516.0        201501
# 12     Median Household Income  2010  120515.0        800324
# 13     Median Household Income  2013   77377.0        264103
# 14     Median Household Income  2011   48365.0        500500
# 15     Median Household Income  2013   40401.0        570601
# 16     Median Household Income  2014   47633.0        570601
# 17     Median Household Income  2014   63500.0        402705
# 18     Median Household Income  2011  213347.0        262100
# 19     Median Household Income  2010   45330.0        542105
# 20     Median Household Income  2013   79235.0        482600
# 21     Median Household Income  2010   64861.0        272301
# 22     Median Household Income  2015   73417.0        278001
# 23     Median Household Income  2013   47935.0        500600
# 24     Median Household Income  2010   34500.0        500402
# 25     Median Household Income  2014   37398.0        533002
# 26     Median Household Income  2016   28375.0        209510
# 27     Median Household Income  2016   71806.0        603500
# 28     Median Household Income  2016   95080.0        702102
# 29     Median Household Income  2014   20972.0        572500
# 30     Median Household Income  2013   98625.0        143902
# ...                        ...   ...       ...           ...
# 16371  Median Household Income  2016  126406.0        111204
# 16372  Median Household Income  2010   47179.0        217200
# 16373  Median Household Income  2012   78232.0        602700
# 16374  Median Household Income  2010   41759.0        201401
# 16375  Median Household Income  2013   47284.0        920038
# 16376  Median Household Income  2010   83000.0        131100
# 16377  Median Household Income  2011   37840.0        127210
# 16378  Median Household Income  2011       NaN        980013
# 16379  Median Household Income  2016   40278.0        542105
# 16380  Median Household Income  2010   21167.0        224200
# 16381  Median Household Income  2011   60385.0        910001
# 16382  Median Household Income  2016   68750.0        406000
# 16383  Median Household Income  2016   78210.0        554514
# 16384  Median Household Income  2013   68793.0        554700
# 16385  Median Household Income  2015  102500.0        571800
# 16386  Median Household Income  2012   91711.0        920012
# 16387  Median Household Income  2015   77958.0        296401
# 16388  Median Household Income  2015   56898.0        532102
# 16389  Median Household Income  2016   29564.0        190402
# 16390  Median Household Income  2012   28735.0        600202
# 16391  Median Household Income  2016   51875.0        600911
# 16392  Median Household Income  2014   39789.0        551101
# 16393  Median Household Income  2010   35167.0        222100
# 16394  Median Household Income  2013   36398.0        120400
# 16395  Median Household Income  2015   94821.0        403702
# 16396  Median Household Income  2016   25517.0        224200
# 16397  Median Household Income  2010  107000.0        920039
# 16398  Median Household Income  2014   61496.0        404903
# 16399  Median Household Income  2013  103922.0        800329
# 16400  Median Household Income  2012   27396.0        535603
#
#                                 Neighborhood
# id
# 1                                Temple City
# 2                                      Watts
# 3                                  Mar Vista
# 4                          Mayflower Village
# 5                             South Pasadena
# 6                              Beverly Hills
# 7                                   Palmdale
# 8                               Shadow Hills
# 9                                      Palms
# 10                                 Lancaster
# 11                                 El Sereno
# 12                              Agoura Hills
# 13                                 Brentwood
# 14                               Pico Rivera
# 15                                Long Beach
# 16                                Long Beach
# 17                                    Pomona
# 18                             Beverly Crest
# 19                                   Compton
# 20                             Monterey Park
# 21                                 Mar Vista
# 22                               Westchester
# 23                               Pico Rivera
# 24                               Pico Rivera
# 25                           Huntington Park
# 26                                  Westlake
# 27                                   Gardena
# 28                              Santa Monica
# 29                                Long Beach
# 30                              Sherman Oaks
# ...                                      ...
# 16371                           Porter Ranch
# 16372                           Mid-Wilshire
# 16373                              Hawthorne
# 16374                              El Sereno
# 16375                          Santa Clarita
# 16376                            Lake Balboa
# 16377                               Van Nuys
# 16378                             El Segundo
# 16379                                Compton
# 16380                             Pico-Union
# 16381                               Palmdale
# 16382                                 Covina
# 16383                               Cerritos
# 16384                                Norwalk
# 16385                             Long Beach
# 16386                        Castaic Canyons
# 16387                              San Pedro
# 16388                             Montebello
# 16389                              Los Feliz
# 16390                               Westmont
# 16391                              Inglewood
# 16392                                 Downey
# 16393                        Adams-Normandie
# 16394                          Panorama City
# 16395                                 Covina
# 16396                             Pico-Union
# 16397                          Santa Clarita
# 16398                           Baldwin Park
# 16399  Unincorporated Santa Monica Mountains
# 16400                             South Gate
#
# [16400 rows x 5 columns]

# %% [markdown]
# ### Transform premise DataFrame

# %% [markdown]
# ### Transform county DataFrame

# %% [markdown]
# ### Create database connection

# %%
connection_string = "root:root@localhost/neighborhoods"
engine = create_engine(f'mysql+pymysql://{connection_string}')

# %%
# Confirm tables that are created in the database 
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     353         if not self._use_threadlocal:
# --> 354             return _ConnectionFairy._checkout(self)
#     355
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
#     484         try:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     137                 with util.safe_reraise():
# --> 138                     self._dec_overflow()
#     139         else:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     134             try:
# --> 135                 return self._create_connection()
#     136             except:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     298
# --> 299         return _ConnectionRecord(self)
#     300
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     427         if connect:
# --> 428             self.__connect(first_connect_check=True)
#     429         self.finalize_callback = deque()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     629             self.starttime = time.time()
# --> 630             connection = pool._invoke_creator(self)
#     631             pool.logger.debug("Created new connection %r", connection)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     324         else:
# --> 325             self.connect()
#     326
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _request_authentication(self)
#     881             if self._auth_plugin_name == "caching_sha2_password":
# --> 882                 auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     883             elif self._auth_plugin_name == "sha256_password":
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/_auth.py in caching_sha2_password_auth(conn, pkt)
#     264     data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 265     pkt = _roundtrip(conn, data)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/_auth.py in _roundtrip(conn, send_data)
#     121     conn.write_packet(send_data)
# --> 122     pkt = conn._read_packet()
#     123     pkt.check_error()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-7-37e81ea71db3> in <module>
#       1 # Confirm tables that are created in the database
# ----> 2 engine.table_names()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in table_names(self, schema, connection)
#    2238         """
#    2239
# -> 2240         with self._optional_conn_ctx_manager(connection) as conn:
#    2241             if not schema:
#    2242                 schema = self.dialect.default_schema_name
#
# /anaconda3/envs/PythonData/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _optional_conn_ctx_manager(self, connection)
#    2022     def _optional_conn_ctx_manager(self, connection=None):
#    2023         if connection is None:
# -> 2024             with self._contextual_connect() as conn:
#    2025                 yield conn
#    2026         else:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2224         return self._connection_cls(
#    2225             self,
# -> 2226             self._wrap_pool_connect(self.pool.connect, None),
#    2227             close_with_result=close_with_result,
#    2228             **kwargs
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2264             if connection is None:
#    2265                 Connection._handle_dbapi_exception_noconnection(
# -> 2266                     e, dialect, self
#    2267                 )
#    2268             else:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1534             util.raise_from_cause(newraise, exc_info)
#    1535         elif should_wrap:
# -> 1536             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1537         else:
#    1538             util.reraise(*exc_info)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2260         dialect = self.dialect
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#    2264             if connection is None:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     352         """
#     353         if not self._use_threadlocal:
# --> 354             return _ConnectionFairy._checkout(self)
#     355
#     356         try:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     749     def _checkout(cls, pool, threadconns=None, fairy=None):
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#     753             fairy._pool = pool
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     481     @classmethod
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
#     484         try:
#     485             dbapi_connection = rec.get_connection()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     136             except:
#     137                 with util.safe_reraise():
# --> 138                     self._dec_overflow()
#     139         else:
#     140             return self._do_get()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     127         if value.__traceback__ is not tb:
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#     131     def u(s):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     133         if self._inc_overflow():
#     134             try:
# --> 135                 return self._create_connection()
#     136             except:
#     137                 with util.safe_reraise():
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     297         """Called by subclasses to create a new ConnectionRecord."""
#     298
# --> 299         return _ConnectionRecord(self)
#     300
#     301     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     426         self.__pool = pool
#     427         if connect:
# --> 428             self.__connect(first_connect_check=True)
#     429         self.finalize_callback = deque()
#     430
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     628         try:
#     629             self.starttime = time.time()
# --> 630             connection = pool._invoke_creator(self)
#     631             pool.logger.debug("Created new connection %r", connection)
#     632             self.connection = connection
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     451
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#     455     def create_connect_args(self, url):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     323             self._sock = None
#     324         else:
# --> 325             self.connect()
#     326
#     327     def _create_ssl_ctx(self, sslp):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     597
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#     601             if self.sql_mode is not None:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _request_authentication(self)
#     880             # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     881             if self._auth_plugin_name == "caching_sha2_password":
# --> 882                 auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     883             elif self._auth_plugin_name == "sha256_password":
#     884                 auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/_auth.py in caching_sha2_password_auth(conn, pkt)
#     263
#     264     data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 265     pkt = _roundtrip(conn, data)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/_auth.py in _roundtrip(conn, send_data)
#     120 def _roundtrip(conn, send_data):
#     121     conn.write_packet(send_data)
# --> 122     pkt = conn._read_packet()
#     123     pkt.check_error()
#     124     return pkt
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# ### Load DataFrames into database

# %%
#Use pandas to load csv converted DataFrame into database
new_income_data_df.to_sql(name='median_household_income', con=engine, if_exists='append', index=False)

# %%
#Confirm data has been added by querying the median_household_income table
pd.read_sql_query('select * from median_household_income', con=engine).head()
